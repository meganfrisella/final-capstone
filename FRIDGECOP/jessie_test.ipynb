# %%
from main import main
main()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-f2a56cbe4ff2> in <module>
# ----> 1 from main import main
#       2 main()
#
# ~\final-capstone\FRIDGECOP\main.py in <module>
#       3 import matplotlib.image as mpimg
#       4 from update_fridge import remove_item, layer_image, propose_regions, parse_food, generate_fridge
# ----> 5 from objects import Fridge
#       6
#       7 def parse_labels():
#
# ~\final-capstone\FRIDGECOP\objects.py in <module>
#       5 import math
#       6 import face_rec
# ----> 7 import voice_rec
#       8 from collections import defaultdict
#       9
#
# ~\final-capstone\FRIDGECOP\voice_rec.py in <module>
#       1 import numpy as np
# ----> 2 from microphone import record_audio
#       3 import pickle
#       4
#       5 f = open("model2.p", "rb")
#
# ModuleNotFoundError: No module named 'microphone'

# %%
from update_fridge import generate_fridge
generate_fridge(2)
